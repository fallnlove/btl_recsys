# %%
# !python3 ./modeling/train.py --params ./configs/mrgsrec_beauty_train_config.json
# Out:
# python3: can't open file '/home/jovyan/./modeling/train.py': [Errno 2] No such file or directory

# %%
# !python3 /home/jovyan/Yusupov/MRGSREC/MRGSRec-562F/modeling/train.py --params /home/jovyan/Yusupov/MRGSREC/MRGSRec-562F/configs/mrgsrec_beauty_train_config.json
# Out:
# [2025-09-16 23:19:39] [DEBUG]: Training config:
# {
#   "experiment_name": "mrgsrec_beauty",
#   "dataset": {
#     "use_user_graph": false,
#     "use_item_graph": false,
#     "graph_dir_path": "/home/jovyan/Yusupov/MRGSREC/MRGSRec-562F/data2/Beauty",
#     "dataset": {
#       "path_to_data_dir": "/home/jovyan/Yusupov/MRGSREC/MRGSRec-562F/data2",
#       "name": "Beauty",
#       "max_sequence_length": 10,
#       "samplers": {}
#     }
#   },
#   "dataloader": {
#     "train": {
#       "batch_size": 256,
#       "drop_last": false,
#       "shuffle": true
#     },
#     "warm_val": {
#       "batch_size": 256,
#       "drop_last": false,
#       "shuffle": true
#     },
#     "validation": {
#       "batch_size": 256,
#       "drop_last": false,
#       "shuffle": false
#     }
#   },
#   "model": {
#     "sequence_prefix": "item",
#     "user_prefix": "user",
#     "positive_prefix": "positive",
#     "embedding_dim": 16,
#     "num_heads": 2,
#     "num_layers": 2,
# ...

# %%
import numpy
import pandas
import torch
import sklearn
import scipy

print(f"numpy=={numpy.__version__}")
print(f"pandas=={pandas.__version__}")
print(f"torch=={torch.__version__}")
print(f"sklearn=={sklearn.__version__}")
print(f"scipy=={scipy.__version__}")
# Out:
# numpy==1.26.4
# pandas==2.0.3
# torch==2.5.1+cu124
# sklearn==1.6.0
# scipy==1.11.4
